# %%
#RNN Merge

from functools import reduce

import pandas as pd
import pickle

# %%
#2010
df_10 = pd.read_pickle("RNN_Test_Sentences_2010")
df_10 = df_10.drop_duplicates()
#2011
df_11 = pd.read_pickle("RNN_Test_Sentences_2011")
df_11 = df_11.drop_duplicates()
#2012
df_12 = pd.read_pickle("RNN_Test_Sentences_2012")
df_12 = df_12.drop_duplicates()
#2013
df_13 = pd.read_pickle("RNN_Test_Sentences_2013")
df_13 = df_13.drop_duplicates()
#2014
df_14 = pd.read_pickle("RNN_Test_Sentences_2014")
df_14 = df_14.drop_duplicates()
#2015
df_15 = pd.read_pickle("RNN_Test_Sentences_2015")
df_15 = df_15.drop_duplicates()
#2016
df_16 = pd.read_pickle("RNN_Test_Sentences_2016")
df_16 = df_16.drop_duplicates()
#2017
df_17 = pd.read_pickle("RNN_Test_Sentences_2017")
df_17 = df_17.drop_duplicates()
#2018
df_18 = pd.read_pickle("RNN_Test_Sentences_2018")
df_18 = df_18.drop_duplicates()
#2019
df_19 = pd.read_pickle("RNN_Test_Sentences_2019")
df_19 = df_19.drop_duplicates()
#2020
df_20 = pd.read_pickle("RNN_Test_Sentences_2020")
df_20 = df_20.drop_duplicates()
#2021
df_21 = pd.read_pickle("RNN_Test_Sentences_2021")
df_21 = df_21.drop_duplicates()
#2022
df_22 = pd.read_pickle("RNN_Test_Sentences_2022")
df_22 = df_22.drop_duplicates()

# %%
df_18
# Out:
#           feature   0 Class   1 Class                     RNN Sentences  \
# 0        believes  1.002269 -1.197326      believes owner irresponsible
# 1         follows  1.002269 -1.197326       follows owner irresponsible
# 2        reflects  1.002269 -1.197326      reflects owner irresponsible
# 3      represents  1.002269 -1.197326    represents owner irresponsible
# 4        requires  1.002269 -1.197326      requires owner irresponsible
# ...           ...       ...       ...                               ...
# 68209     slender -4.276229  2.633238    zoom past slender moped afghan
# 68210    handsome  1.395307 -2.330738   zoom past handsome moped afghan
# 68211         fat -6.837672  4.608534        zoom past fat moped afghan
# 68212        thin -4.472152  2.688693       zoom past thin moped afghan
# 68213   beautiful -5.943734  3.881133  zoom past beautiful moped afghan
#
#           source  snet id POS tag  0 Class Benchamark  1 Class Benchmark  \
# 0          power    11405    Verb            1.202535          -1.453593
# 1          power    11405    Verb            1.202535          -1.453593
# 2          power    11405    Verb            1.202535          -1.453593
# 3          power    11405    Verb            1.202535          -1.453593
# 4          power    11405    Verb            1.202535          -1.453593
# ...          ...      ...     ...                 ...                ...
# 68209  Apperance     9365    Noun           -2.341069           0.865455
# 68210  Apperance     9365    Noun           -2.341069           0.865455
# 68211  Apperance     9365    Noun           -2.341069           0.865455
# 68212  Apperance     9365    Noun           -2.341069           0.865455
# 68213  Apperance     9365    Noun           -2.341069           0.865455
#
#        Class 0 Differential  Class 1 Differential
# 0                 -0.200265              0.256266
# 1                 -0.200265              0.256266
# 2                 -0.200265              0.256266
# 3                 -0.200265              0.256266
# 4                 -0.200265              0.256266
# ...                     ...                   ...
# 68209             -1.935160              1.767783
# 68210              3.736376             -3.196193
# 68211             -4.496602              3.743079
# 68212             -2.131082              1.823238
# 68213             -3.602664              3.015678
#
# [63564 rows x 11 columns]

# %%
df_list = [df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22]
dfs = [df.drop_duplicates()for df in df_list]
dfs = [df.drop(df.columns[[1,2,3,5,6,7,8]],axis = 1) for df in dfs]
dfs = [df.groupby(['feature','source']).mean()for df in dfs]

# %%
data_merge = reduce(lambda left, right: pd.merge(left , right, on = ['feature','source'],how = "inner"), dfs)

# %%
data_merge
# Out:
#                          2010_Class_0_Differential  2010_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.467642                   0.330006
# abuse       Violence                      0.402538                  -0.313011
# accepting   communality                   0.706838                  -0.539421
# accomplice  Violence                      0.505722                  -0.203365
# achievement agency                       -0.170459                   0.039830
# ...                                            ...                        ...
# worst       Violence                     -0.200776                   0.070056
# wound       Violence                      0.262786                  -0.199596
# wrath       Violence                      0.391354                  -0.242226
# wrongdoer   Violence                     -0.300120                   0.144667
# yell        Violence                      0.015367                  -0.050811
#
#                          2011_Class_0_Differential  2011_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.416206                   0.557531
# abuse       Violence                     -0.046804                   0.149308
# accepting   communality                  -0.731335                   0.735922
# accomplice  Violence                      0.274223                  -0.612138
# achievement agency                        0.055826                  -0.090720
# ...                                            ...                        ...
# worst       Violence                     -0.161162                   0.221106
# wound       Violence                      0.130696                  -0.187797
# wrath       Violence                      1.059179                  -1.846583
# wrongdoer   Violence                      0.255476                  -0.402141
# yell        Violence                      0.459413                  -0.972865
#
#                          2012_Class_0_Differential  2012_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.293335                   0.316895
# abuse       Violence                      0.191712                  -0.189628
# accepting   communality                   0.581360                  -0.613574
# accomplice  Violence                      0.213044                  -0.191489
# achievement agency                       -0.057594                   0.047112
# ...                                            ...                        ...
# worst       Violence                     -0.348954                   0.312044
# wound       Violence                      0.226987                  -0.226813
# wrath       Violence                      0.053713                  -0.061339
# wrongdoer   Violence                     -0.166919                   0.155724
# yell        Violence                      0.002686                  -0.009259
#
#                          2013_Class_0_Differential  2013_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.795730                   0.878671
# abuse       Violence                     -0.226226                   0.172849
# accepting   communality                  -0.787155                   1.024067
# accomplice  Violence                      0.731408                  -0.623442
# achievement agency                       -0.714443                   0.726457
# ...                                            ...                        ...
# worst       Violence                     -0.029530                   0.060343
# wound       Violence                      0.225539                  -0.211735
# wrath       Violence                     -0.911706                   1.051907
# wrongdoer   Violence                     -0.106274                   0.113211
# yell        Violence                     -0.031124                   0.087071
#
#                          2015_Class_0_Differential  2015_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.435364                   0.493208
# abuse       Violence                     -0.031988                   0.024764
# accepting   communality                  -1.267632                   1.700003
# accomplice  Violence                      1.817646                  -1.923504
# achievement agency                       -0.071946                   0.136111
# ...                                            ...                        ...
# worst       Violence                      0.177868                  -0.186417
# wound       Violence                      0.327514                  -0.368409
# wrath       Violence                     -1.433369                   1.801654
# wrongdoer   Violence                      0.349743                  -0.340887
# yell        Violence                      2.305402                  -2.335312
#
#                          ...  Class 0 Differential  Class 1 Differential  \
# feature     source       ...
# abduct      Violence     ...             -0.297769              0.026378
# abuse       Violence     ...              0.037126              0.029104
# accepting   communality  ...              0.021354             -0.221027
# accomplice  Violence     ...              0.552804             -0.773852
# achievement agency       ...             -0.452144              0.419050
# ...                      ...                   ...                   ...
# worst       Violence     ...              0.108450             -0.080209
# wound       Violence     ...             -0.106749              0.100084
# wrath       Violence     ...              0.200458             -0.466324
# wrongdoer   Violence     ...             -0.260473              0.275083
# yell        Violence     ...             -0.022192              0.047054
#
#                          2019_Class_0_Differential  2019_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.308207                   0.400211
# abuse       Violence                      0.029301                  -0.034420
# accepting   communality                   0.469182                  -0.592037
# accomplice  Violence                      0.874973                  -1.103531
# achievement agency                       -0.039263                   0.019766
# ...                                            ...                        ...
# worst       Violence                     -0.388767                   0.428894
# wound       Violence                     -0.107585                   0.137108
# wrath       Violence                     -0.666457                   0.670183
# wrongdoer   Violence                     -0.147866                   0.120236
# yell        Violence                      0.901993                  -1.125691
#
#                          2020_Class_0_Differential  2020_Class_1_Differential  \
# feature     source
# abduct      Violence                      0.120040                  -0.067164
# abuse       Violence                     -0.203941                   0.122741
# accepting   communality                  -1.760568                   2.114764
# accomplice  Violence                      0.986482                  -0.832061
# achievement agency                        0.033534                  -0.054739
# ...                                            ...                        ...
# worst       Violence                     -0.216201                   0.181191
# wound       Violence                      0.063749                  -0.095676
# wrath       Violence                     -0.048442                   0.115475
# wrongdoer   Violence                      0.319792                  -0.316600
# yell        Violence                      0.005528                  -0.001117
#
#                          2021_Class_0_Differential  2021_Class_1_Differential  \
# feature     source
# abduct      Violence                     -0.456343                   0.376184
# abuse       Violence                     -0.244117                   0.166810
# accepting   communality                  -0.457954                   0.363853
# accomplice  Violence                      0.830304                  -0.651090
# achievement agency                        0.239560                  -0.184171
# ...                                            ...                        ...
# worst       Violence                     -0.368370                   0.333826
# wound       Violence                     -0.125826                   0.073626
# wrath       Violence                      0.542054                  -0.387045
# wrongdoer   Violence                      0.349200                  -0.223479
# yell        Violence                      0.452151                  -0.275084
#
#                          2022_Class_0_Differential  2022_Class_1_Differential
# feature     source
# abduct      Violence                     -0.599757                   0.508591
# abuse       Violence                     -0.345552                   0.289391
# accepting   communality                   0.370222                  -0.321197
# accomplice  Violence                      1.063775                  -0.871602
# achievement agency                       -0.130230                   0.104858
# ...                                            ...                        ...
# worst       Violence                      0.177556                  -0.151450
# wound       Violence                      0.051840                  -0.049084
# wrath       Violence                      0.039228                  -0.008756
# wrongdoer   Violence                     -0.016683                   0.012484
# yell        Violence                     -0.079726                   0.069054
#
# [548 rows x 24 columns]

# %%
data_merge.to_excel("RNN 2010 and 2012.xlsx")
