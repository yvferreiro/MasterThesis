# %%
import pandas as pd
from functools import reduce
import pickle
import numpy as np
#pandas 1.4.4
#python version
#

# %%
power_agency = "Sap et al. -Connotation Frames of Agency and Power.csv"

power_agency = pd.read_csv(power_agency)
power_agency[["agency_1","agency_classifier"]]= power_agency["agency"].str.split("_",expand=True)
power_agency[["power_1","power_classifier"]]= power_agency["power"].str.split("_",expand=True)
power_agency = power_agency.drop(power_agency[["agency","power", "agency_1", "power_1"]], axis= 1)
power_agency=power_agency.drop(columns='agency_classifier')
power_agency = power_agency[power_agency['power_classifier'].isin(['agent','equal']) != True]
power_agency = power_agency.dropna()
power_agency['source']='power'
power_agency.set_axis(['feature', 'weight', 'source'], axis='columns', inplace=True)

# %%
communality = "Lawson et al. - Communality.csv"
communality = pd.read_csv(communality)
communality = communality.drop(columns=['Valence Mean', 'Valence SD','Communality SD'])
communality['source']='communality'
communality.set_axis(['feature', 'weight', 'source'], axis='columns', inplace=True)



agency = "Lawson et al. - Agency Words.csv"
agency = pd.read_csv(agency)
agency = agency.drop(agency.columns[[2,3,4]], axis=1)
agency = agency.rename(columns={'Word':'feature','Agency Mean':'weight'})
agency['source']='agency'

# %%
apperance = "Garg_apperance_words.csv"

apperance = pd.read_csv(apperance)

violence = "Violence_Grievence_Dicitonary.csv"
violence = pd.read_csv(violence)
violence = violence.rename(columns={'weights':'weight'})

# %%
#2010
df_10 = pd.read_pickle("RESULTS10_coef_high.pickle")
df_10.rename(columns = {'coef':'2010_c'}, inplace = True)
#df_10 = df_10.drop(columns=['coef_type'])
#2011
df_11 = pd.read_pickle("RESULTS11_coef_high.pickle")
df_11.rename(columns = {'coef':'2011_c'}, inplace = True)
#2012
df_12 = pd.read_pickle("RESULTS12_coef_high.pickle")
df_12.rename(columns = {'coef':'2012_c'}, inplace = True)
#2013
df_13 = pd.read_pickle("RESULTS13_coef_high.pickle")
df_13.rename(columns = {'coef':'2013_c'}, inplace = True)
#2014
#df_14 = pd.read_pickle("RESULTS14_coef_high.pickle")
#df_14.rename(columns = {'coef':'2014_c'}, inplace = True)
#2015
df_15 = pd.read_pickle("RESULTS15_coef_high.pickle")
df_15.rename(columns = {'coef':'2015_c'}, inplace = True)
#2016
df_16 = pd.read_pickle("RESULTS16_coef_high.pickle")
df_16.rename(columns = {'coef':'2016_c'}, inplace = True)
#2017
df_17 = pd.read_pickle("RESULTS17_coef_high.pickle")
df_17.rename(columns = {'coef':'2017_c'}, inplace = True)
#2018
df_18 = pd.read_pickle("RESULTS18_coef_high.pickle")
df_18.rename(columns = {'coef':'2018_c'}, inplace = True)
df_18 = df_18.drop(columns= 'coef_type')
#2019
df_19 = pd.read_pickle("RESULTS19_coef_high.pickle")
df_19.rename(columns = {'coef':'2019_c'}, inplace = True)
df_19 = df_19.drop(columns= 'coef_type')
#2020
df_20 = pd.read_pickle("RESULTS20_coef_high.pickle")
df_20.rename(columns = {'coef':'2020_c'}, inplace = True)
df_20 = df_20.drop(columns= 'coef_type')
#2021
df_21 = pd.read_pickle("RESULTS21_coef_high.pickle")
df_21.rename(columns = {'coef':'2021_c'}, inplace = True)
df_21 = df_21.drop(columns= 'coef_type')
#2022
df_22 = pd.read_pickle("RESULTS22_coef_high.pickle")
df_22.rename(columns = {'coef':'2022_c'}, inplace = True)
df_22 = df_22.drop(columns= 'coef_type')

# %%
df_list = [df_10, df_11, df_12, df_13, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22]
#df = pd.merge(df_list, right on='feature', how='outer')

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), df_list)
# Out:
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_9340/2482447091.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'coef_type_x', 'year_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), df_list)
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_9340/2482447091.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'coef_type_x', 'year_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), df_list)
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_9340/2482447091.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'year_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), df_list)
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_9340/2482447091.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'year_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), df_list)
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_9340/2482447091.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'year_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), df_list)

# %%
with open('results_22.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
PAC_words = [power_agency, communality, agency, violence, apperance]
df_attempt = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), PAC_words)
# Out:
# /var/folders/g0/r571pkwj6973dlq1m_v76wp40000gn/T/ipykernel_9340/301925258.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'source_x', 'weight_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_attempt = reduce(lambda  left,right: pd.merge(left,right,on=['feature'],how='outer'), PAC_words)

# %%
PAC_words = [power_agency, communality, agency, violence, apperance]
result = pd.concat(PAC_words)
result = result.drop(columns='weight')
result = result.drop(columns='weights')

# %%
result
# Out:
#         feature     source
# 8   accompanies      power
# 15     achieves      power
# 28      admires      power
# 29       admits      power
# 31       adores      power
# ..          ...        ...
# 20         weak  Apperance
# 21         thin  Apperance
# 22       pretty  Apperance
# 23    beautiful  Apperance
# 24       strong  Apperance
#
# [864 rows x 2 columns]

# %%
words = result["feature"].tolist()
type(words)
# Out:
# list

# %% [markdown]
# **Getting the Coefficients out of Log Reg**

# %%
vocabu = results['tfidf'].vocabulary_

word_vector = np.zeros(len(vocabu))
for word in words:
    if word in vocabu:
        index = vocabu[word]
        word_vector[index] = 1

coefficients = results['model'].coef_[0]
word_coefficients = {word: coefficient for word, coefficient in zip(vocabu.keys(), coefficients)}

for word in words:
    if word in word_coefficients:
        print(f"{word}: {word_coefficients[word]}")
# Out:
# accompanies: -0.3086232862919929
# admires: 1.0427783387677627
# admits: -0.49699866209287324
# adores: 0.8712351194539163
# announces: 0.04231750193000514
# appeals: 0.4536934114296125
# ascends: -0.0993120053610293
# asks: 0.521973399926325
# attends: 0.2822483843269907
# awaits: 0.6079726816859021
# becomes: 0.2510233411188337
# begs: 0.2602632304831307
# benefits: 0.7264495364743904
# calls: 0.3001266965166442
# celebrates: 1.053958530473661
# cheers: 0.1632456089154041
# compiles: 0.4756143497175679
# concedes: 0.371584623897179
# congratulates: -0.13961775031904886
# contributes: -0.2638319119538591
# copies: 0.24230941751125407
# donates: 0.0
# dreams: -0.41806675443773317
# ducks: -0.44720702257217615
# endures: 0.0023811583618761857
# experiences: 0.18079483238129615
# explains: -0.5151561162397614
# fancies: 0.008252323966231743
# fans: -0.1922998910968245
# fears: -0.7262436618832214
# fulfils: -0.769045010716495
# greets: -0.1810132333527049
# guards: 0.22100382905423327
# hears: -1.5076336851753835
# hopes: -0.19718408664800405
# interests: -0.22196343743699065
# lacks: 0.2133442049480644
# learns: -0.4725803957797805
# listens: -0.20339693212211812
# massages: 0.11015193514185746
# mentions: -0.05995296867452292
# minds: 0.7547656716776026
# notes: -0.19913085002841852
# obliges: -0.14351184636343214
# owes: 0.0
# pleads: 0.2790246194683351
# portrays: 0.5417034426077939
# predicts: -0.22509251463432364
# prefers: -0.2379676216130007
# receives: 0.2510983660839659
# recognises: -0.6234803398939712
# regrets: 0.07042905108488241
# represents: 0.12878167191565215
# resents: -0.09248503674217515
# responds: 0.0
# struggles: -0.1487432096495241
# suffers: 0.3198494323621287
# thanks: 0.49772420186919786
# tips: -0.9540974621588921
# traces: -0.16192510460122098
# trusts: 0.25988032240944614
# undergoes: -0.15039216712012288
# undertakes: 0.4148876202940884
# upholds: -0.148356186414393
# values: -0.22363733478143774
# visits: -0.22866944559640726
# wants: 0.0
# weathers: -0.3379837917404966
# witnesses: 0.1893840995638345
# accepting: 0.13544839243665122
# affectionate: 0.15109037551597776
# agreeable: 0.0
# altruism: 0.0
# altruistic: -0.1383156645447653
# attachment: -0.245789509821852
# belonging: -0.3561339842526649
# benevolence: 0.0
# caring: 0.16944827031662194
# cheerful: -0.15373229280934075
# civility: 0.0
# closeness: 0.0
# communal: -0.16992301237052468
# communicative: -0.0050227856789385175
# compassion: 0.37522226408105613
# compassionate: 0.0
# compromising: 0.30501677561145707
# connected: -0.002986520948481209
# connections: -1.311550658207903
# conscientious: -0.12439761303071177
# considerate: -0.14967477856907524
# consideration: -0.22575696477324894
# cooperation: -0.6268709901389706
# cooperative: 0.18077072918750764
# dependable: -0.22772650211327772
# dependency: 0.134879406755014
# dependent: -0.11538676778849011
# duty: 0.3051830578164172
# enthusiastic: -0.11296747024573717
# equality: -0.00734532996141374
# fair: -0.2234499470853763
# faithful: -0.0912428635760373
# flexible: 0.337636294863587
# forgiveness: 0.21146466440690975
# forgiving: -0.26029196007349015
# friendliness: -0.13958810105624173
# friendly: 0.502340247395901
# generous: 0.8253826017931466
# gentle: -0.0636374393294281
# good: 0.28436004108135615
# goodhearted: -0.5180287296786542
# gracious: 0.6004094292409528
# harmony: -0.6415689909332527
# helpful: 0.13748911509526834
# honest: 0.03516469858259887
# honesty: -0.3751586860322811
# hospitable: 0.0
# humble: -0.1371964475589363
# humility: 0.8979853457583775
# influence: 0.9483255039697794
# interdependent: 0.2758306370938304
# interpersonal: 0.012379113048797664
# just: -0.02669782681000532
# kind: 0.026998388708479593
# love: -0.3111991248286964
# loyal: 0.412382931007814
# loyalty: 0.174209556821067
# moral: -0.34171796544624755
# nice: -0.15088934213990846
# nurturing: -0.09176322376566148
# optimistic: 0.37049603635777517
# patient: 0.34386989929713435
# pleasant: -0.4814085611586397
# polite: 0.25695620479650166
# popular: 0.19077010233568648
# reasonable: -0.15748148504389425
# reliable: -0.1050829798708671
# respectful: -0.09454036405499355
# selfless: -0.11480327247521176
# sensitivity: 0.8219546622490983
# sincere: 0.5391739515675794
# sociable: -0.6660031665596375
# social: 0.249500572025547
# supportive: -0.027911320221279564
# sympathetic: -0.6940891489599513
# talkative: 0.3516226896295437
# thoughtful: 0.3225856836087072
# tolerant: 0.3563777544967071
# trust: 0.0
# trusting: -0.27864955093607646
# trustworthy: 1.8778041089734847
# truthful: 0.22904121347727566
# understanding: -0.1308586493527387
# warm: -0.660367149323565
# warmth: -0.13241292269762606
# welcoming: 0.22135941875145165
# wise: -0.2196415328187114
# achievement: 0.36940165922740886
# active: -0.5973538628460335
# adamant: -0.1855463546429159
# aggressive: -0.11106404713457181
# ambition: 0.5127327839826903
# ambitious: 0.38478018053612073
# analytical: 0.15114950000567962
# assert: 0.27384893003372396
# assertive: -0.3106081047148407
# assertiveness: 0.19794503121427062
# assured: 0.36815261942255545
# autonomous: 0.3157431827644509
# autonomy: 0.11311824406903447
# bold: 0.12654333942631277
# bossy: -0.3970722838391339
# brave: 0.27828375015880136
# brilliant: -0.4125593110437741
# capability: -0.2124708659704825
# capable: -0.09045669157432107
# clever: -0.9278579053375742
# command: 0.07513518159694538
# competence: -0.15588481730155765
# competent: -0.20825644756445466
# competitive: 1.1135565104270235
# competitiveness: 1.1318330457014232
# confidence: -0.1009466642670626
# confident: 0.14001329317339595
# convincing: -0.2935543991520932
# creative: 0.6577671059626073
# cunning: -0.05816199566808678
# daring: -0.22129133941311685
# decisive: 0.48135682811280217
# determined: -0.5190472319626788
# diligent: 0.06640635175363414
# direct: 0.07875893183822996
# dominant: -0.1271854556279429
# dynamic: 0.6573687006407166
# educated: 0.702157392373804
# effective: 0.13593378137022621
# efficient: -0.1904014098707466
# energetic: -0.15400237097109878
# exploration: 0.27263476326885144
# fast: -0.3148850863810302
# freedom: -0.4163615710133505
# hardworking: 0.0
# imaginative: -0.4725986482669534
# independence: 0.0
# independent: -0.43088666675004816
# individual: -0.03546586072752587
# individualistic: -0.19201720602515063
# industrious: 0.1597955516505014
# ingenious: 0.005480934109682911
# insightful: 0.259481602275452
# intellectual: -0.34353630954614817
# intelligent: 0.05436774957387905
# knowledgeable: 0.0
# leader: -0.22771796388722676
# logical: -0.12501061508461017
# meticulous: -0.09198583977953426
# original: -0.7112899140859874
# outspoken: -0.28588122746908745
# perceptive: 0.5548248270506817
# persistent: 0.15174333855042313
# power: 0.3709062200351069
# powerful: -0.2820003315250438
# practical: -0.09521164167197914
# proud: 0.0
# rational: 0.017608799395595672
# realist: -0.09742381902094578
# recognition: 0.09190658344319216
# resilient: -0.12189741019934051
# resourceful: 0.2100436369325224
# serious: -0.21452198577544776
# sharp: -0.31287057057337464
# smart: 0.10965867197229447
# status: 0.0
# strong: 0.343181000437212
# superiority: 0.36354220878141336
# tough: -0.21614153815636641
# unique: 0.4590454955546971
# unwavering: 0.11258959641620077
# vigorous: -0.18700357941848852
# beef: -0.22692266748923606
# lose: 0.9786337128010362
# difficult: -0.4140181434463342
# elicit: 0.22291898334105162
# denigrate: -0.06517195777400192
# passion: -0.15951344592277858
# pressure: -0.1397372869298691
# differ: 0.18306681959871454
# crush: -0.2537502577748641
# pointless: 0.2729858789896344
# swing: 0.25029117982318344
# hack: 0.0
# anxiety: 0.0
# sexual: -0.26263274693253397
# jihad: -0.2839037996625686
# scrape: -0.05487984793914932
# crass: 0.3790074143360986
# defeat: 0.22796792616697303
# red: -0.11555475483933987
# mean: 1.1707282424943442
# despair: 0.22564830755030732
# ram: -0.2723074699466754
# oppose: 0.35521101887879725
# person: 0.2934565307816805
# human: -0.21923310138153326
# fire: -0.3705415914397973
# command: 0.07513518159694538
# sentence: -0.16032393629277192
# screech: -0.28851268513352357
# round: -0.5035545436908174
# hamstring: -0.031032344185649163
# prejudice: 0.0
# wipeout: -0.09120869221837881
# spree: 0.7820141940780696
# detention: 0.98732868940075
# complain: 0.25661346101564414
# dissonance: -0.058808991878624504
# evasive: -0.06938682523768017
# imperialist: -0.10350331889051026
# discontent: -0.20054397885616784
# disgrace: -0.7919492819916802
# useless: -0.0356091763019144
# domestic: -0.15230445139559642
# wild: 0.3730670433018447
# strength: -0.5197115219940418
# impulse: 0.2110135199781283
# accomplice: -0.20588607913008122
# annoy: 1.8404548826517284
# atomic: 0.6233631830460932
# intend: -0.17828008593384773
# allege: -0.15925113093626986
# rip: 0.46847493708189153
# anguish: -0.20785288289209397
# opposite: -1.0305828009001596
# dread: 0.477370966218619
# deprive: -0.4573333902474173
# inexplicable: 0.0
# demise: -0.9173139597622497
# campaign: -0.17524864162671955
# undercut: 0.17697748931776308
# puncture: -1.4016232619606157
# resent: -0.5325892840428373
# increase: -0.16683893728729055
# unease: -0.9695100350271947
# consequence: -0.1064237088364969
# deploy: 0.0
# scene: 0.22209125747642405
# rebel: 0.20684315360170205
# disagree: -0.49934408036162375
# defend: -0.23482024033601945
# affray: -1.230217799680846
# thrust: -0.7551177827321275
# dissatisfaction: 0.352462000309057
# meaningless: -0.09401980336610932
# mangle: 0.0
# disillusioned: -0.8494594060701164
# troop: 0.058315736053900634
# extreme: -0.18706176782224224
# grief: 0.6924866255157711
# demeaning: -0.45560100557247907
# ire: -0.021638229746022707
# affect: -0.24129693919027323
# worst: 0.28847976257388636
# invasive: 0.34485275092484025
# encounter: -0.43396705520229023
# arm: 0.3303828116098372
# loss: 0.5146463391050532
# unpredictable: -0.12189821253895834
# convict: -0.8007663746500532
# struggle: 0.0
# raid: -0.9453610345202069
# mistrust: -0.34610022725482364
# shameless: -0.21074032450744182
# corrupt: -0.1276200292923854
# worry: 0.17640762228056378
# theft: 0.2930832556807652
# incite: -0.19404811755804147
# guard: -0.22810280412171918
# poison: -0.15946248718554754
# unhappy: -0.9911233336391648
# craze: 0.3869548536395481
# bestiality: 0.2737062497221782
# protest: 0.6264856246571422
# cry: 0.0
# raze: 0.3277775500616242
# cult: -0.0757830474235676
# munition: 0.439669669116234
# serious: -0.21452198577544776
# vehement: -0.12133738146896235
# issue: -0.3271203434865645
# beast: 0.2040379411775807
# animosity: -0.6598309137502566
# nuclear: 0.1835064564535078
# gash: 0.40937019876447045
# trouble: -0.6418764789902484
# grave: -1.2568723048977477
# suspect: 0.06156597436493508
# hysterical: -0.25427926199240264
# ruin: 0.4342761705998278
# army: -0.27098749177992076
# demolition: -0.10533734311041747
# blast: -0.17892775186075532
# detest: -0.1680359805189456
# roughshod: -0.574956217910567
# mad: -0.16633291552301016
# severed: 0.33218692450394127
# perpetrate: -0.3559844683352798
# damage: 0.13187833350500697
# investigate: -1.206962052050215
# charge: 0.5961738552614941
# burglary: -0.3932030739148031
# behavior: 0.07012131702665823
# jab: -0.2165831321799088
# slice: 1.1101592536419034
# machete: 0.17014675286060568
# inmate: 0.4420661694770388
# tear: 0.7125467662921787
# snap: 0.1545687172807888
# foe: -0.556497514287688
# fright: -0.14901651882205663
# collision: -0.14760356001844832
# die: -0.2698945964920767
# yell: 0.3978797475845127
# bite: -0.22945420386232418
# imprison: 0.08305416639501846
# irate: -0.21344847754837573
# intent: -0.3013567443177154
# mindless: 0.15908189364499847
# risk: -0.4654014328129389
# fought: -0.12537507164757367
# adversary: -0.03555162879744611
# tense: -0.1441826783885586
# inflame: -0.22292147800779513
# harass: -0.5701430706816196
# showdown: -0.45810932078278677
# decease: 0.0
# crusade: 0.30794508151318106
# dispute: -0.2846630916494432
# hassle: -0.07123689010038729
# loot: 0.5050424473790196
# peril: 0.2450548433055401
# vandal: 0.3706251166888901
# spite: -0.19593114881018506
# worse: -0.8459280316784886
# target: -0.11787229543244039
# soldier: 0.03475922367686375
# detriment: -0.19137970275202296
# scuffle: -0.414487233982763
# incident: 0.14153470121159478
# radical: 0.7246673588386012
# shriek: -0.42945836112394775
# bitter: 0.41443649147728195
# jealousy: 0.19787304175495063
# suicide: 0.060240919546912526
# vicious: -0.11982743374131767
# inflict: 0.23760531838915253
# snipe: -0.3605773185626367
# push: -0.21844536749385907
# power: 0.3709062200351069
# wrath: -0.035307384916604005
# stress: -0.7835560948473739
# criminal: -0.009485140608090303
# provoke: 0.0
# kidnap: 0.00911974501062075
# racist: -0.1459322903934492
# offence: -0.5186991494676004
# displeasure: -0.2104872992099525
# thief: -0.13091883659451062
# agitate: 0.6705725186115341
# outrage: -0.28143050578631584
# shrapnel: 0.16443986545276432
# demolish: -0.27127283628185517
# maim: 0.32952555092591584
# molest: -0.16039413770367536
# confront: 0.29454868703302045
# slash: 0.5332530293904856
# destroy: -0.5412923532154569
# jail: 0.2853441235679844
# aggravate: -0.06675941824556364
# culprit: 0.20742132856751483
# cut: 0.24400374387422377
# trial: -0.37685248497137097
# senseless: 0.0
# escalate: -0.15179895245686645
# traffic: 0.37941066504499416
# fear: -0.24921825136821985
# threat: 0.0
# missile: 0.2752563493820326
# gunman: 0.1432319471490317
# abduct: 0.19394942340273014
# ambush: -0.5840627263294708
# racism: 0.0
# bad: -0.37342657643826027
# grievous: -0.5914380467556983
# enemy: 0.1900479288516862
# law: -0.6543919680167045
# felony: -0.0995588746849188
# endanger: 0.0
# oppressor: -0.5797366471416204
# oppress: 0.03230156929159252
# police: -0.2511049500824992
# gunshot: 0.0
# savage: 0.21390718518118448
# shout: 0.9291248148487855
# onslaught: 0.13380839390905164
# disgust: 0.2733214792834202
# fatal: -0.29182167509354817
# aggressive: -0.11106404713457181
# strike: -0.22528108661175866
# slay: 0.4880768410496284
# afraid: -0.014508980366662726
# obliterate: 0.44937122389484363
# distress: -0.08363792162821704
# arrest: 0.5496547884604558
# explode: 0.1517663294259353
# unruly: 0.18406328537538624
# bleed: 0.45717275793760515
# suffer: -0.13049104726597555
# ruthless: -0.08113677723692587
# unsafe: -0.6619277072240157
# mayhem: 0.715101289641158
# trauma: 0.3136246635480951
# altercation: -0.23695780113992268
# barbaric: 0.5556189484423618
# grab: 0.19418749567815477
# prey: -1.119485759459358
# destruct: 0.21371235042692796
# dead: -0.19754794536419307
# kick: 0.0
# death: -0.7539812085301858
# force: -0.14885072365491794
# bang: -0.08753670944616654
# rape: -0.17841841442055809
# burn: -0.06674259625759069
# riot: 0.2991282204387697
# bully: -0.6058195305267196
# bloody: 0.18202843268122754
# explosive: -0.05831592820413001
# prison: 0.0
# tension: -0.053975935616697855
# felon: -0.1364074488432315
# hit: 0.18014109449885576
# angry: 0.2410774102784588
# knife: -1.1392457454264782
# scream: 0.07019869351915443
# pain: 0.0
# casualty: 0.5552224702436098
# weapon: 0.19372276610458605
# threaten: 0.0
# bloodthirsty: -0.1028258801166356
# warfare: -0.15681563935707293
# offend: -0.10915085615730331
# artillery: -0.1950442087531427
# fierce: 0.2296013639588892
# grenade: 0.2325582979952372
# gun: 0.10895547502452665
# execute: 0.3716305374830002
# smash: -0.19984826247813828
# arson: -0.31672964686188276
# wound: 0.0
# battle: 0.2368169827207724
# hate: 0.42880805628511454
# hostile: 0.3155225534753104
# gang: -0.12966271336627896
# danger: 0.7535906392775068
# military: 0.3209801630476935
# harsh: 0.4770912393745167
# gunmen: -0.10677066537644805
# harm: 0.09182259979003103
# ammunition: -0.6940432986751897
# horrific: -0.7031717151776782
# combat: 0.32816189384785754
# kill: 0.2129435180702839
# assailant: -1.4310216428534148
# intimidate: 0.4291791603840353
# shot: 0.0
# rampage: -0.38164740286789484
# weaponry: 0.2579492492708298
# struck: -0.19864919834668443
# sicken: -0.14212307382591316
# attack: 0.6296975074784392
# victim: 0.3872009450302156
# stab: -0.09256353237768876
# cruel: -0.19382281147694652
# aggressor: 0.0
# injure: -0.37234635550845174
# rapist: -0.05506509251157233
# mutilate: 0.2455356072335213
# blood: -0.06513949106423765
# fury: -0.04431718562869732
# brawl: -0.07107063314942506
# terrorist: -0.29644926152168927
# anger: -0.28883298832355203
# murder: -0.0892861291240231
# warhead: 0.8073748928195962
# bomb: 0.40419948177478643
# abuse: 0.3315556456697452
# bomber: -0.04142756706739143
# hurt: -0.014508760593135734
# war: 0.032575134785436534
# punch: -0.4022579519713267
# bruise: -0.1272524048662577
# assault: -0.11079090569593329
# robbery: 0.8974957754230866
# hatred: -0.16077100392631552
# brute: -1.179363306814037
# crime: 0.641350369752388
# bullet: 0.21333096198336016
# terror: -1.8177464889159256
# injury: -0.11701331929622653
# gore: -0.41194589336164106
# shoot: -0.14895493371992807
# brutal: 0.4470604181604882
# fight: -0.16625953900912643
# menace: -0.1484706078376447
# outburst: 0.0
# rage: -0.7532347901757241
# conflict: -0.1595750662231392
# bloodshed: -0.4727756734485431
# violence: 0.22560889596117675
# violent: 0.10703993713676435
# alluring: -0.1426373734124774
# homely: -0.6844423015019474
# plump: 0.6158614087883246
# gorgeous: -0.19694260128084534
# slim: -0.2309335508031802
# bald: -0.3192782734918632
# athletic: 0.34982145779965373
# fashionable: -0.13770103328553318
# stout: -0.21072457883442453
# ugly: -1.1298307619885162
# muscular: 0.222885992700059
# slender: -0.13136491393473204
# feeble: -0.6468886008354182
# handsome: 0.5945684820321017
# healthy: 0.7258336730139585
# attractive: -0.1809468122018197
# fat: -0.032289010490276146
# weak: -0.15534059359085534
# thin: -0.1757360995620286
# pretty: 0.634639177068644
# beautiful: -0.06851441996252573
# strong: 0.343181000437212

# %%
result.to_csv("full_word_list")

# %%
from nltk import word_tokenize, pos_tag, pos_tag_sents
import pandas as pd
df = result
texts = df['feature'].tolist()
tagged_texts = pos_tag_sents(map(word_tokenize, texts))
df['POS'] = tagged_texts
df
# Out:
#         feature     source                   POS
# 8   accompanies      power  [(accompanies, NNS)]
# 15     achieves      power     [(achieves, NNS)]
# 28      admires      power      [(admires, NNS)]
# 29       admits      power       [(admits, NNS)]
# 31       adores      power       [(adores, NNS)]
# ..          ...        ...                   ...
# 20         weak  Apperance          [(weak, JJ)]
# 21         thin  Apperance          [(thin, NN)]
# 22       pretty  Apperance        [(pretty, RB)]
# 23    beautiful  Apperance     [(beautiful, NN)]
# 24       strong  Apperance        [(strong, JJ)]
#
# [864 rows x 3 columns]

# %%
df3 = df.POS.apply(pd.Series)
df3.columns = ['1', '2','3','4']
df3['a'] = df3['1'].str[1]
df3['b'] = df3['1'].str[0]

# %%
df3
# Out:
#                      1    2    3    4    a            b
# 8   (accompanies, NNS)  NaN  NaN  NaN  NNS  accompanies
# 15     (achieves, NNS)  NaN  NaN  NaN  NNS     achieves
# 28      (admires, NNS)  NaN  NaN  NaN  NNS      admires
# 29       (admits, NNS)  NaN  NaN  NaN  NNS       admits
# 31       (adores, NNS)  NaN  NaN  NaN  NNS       adores
# ..                 ...  ...  ...  ...  ...          ...
# 20          (weak, JJ)  NaN  NaN  NaN   JJ         weak
# 21          (thin, NN)  NaN  NaN  NaN   NN         thin
# 22        (pretty, RB)  NaN  NaN  NaN   RB       pretty
# 23     (beautiful, NN)  NaN  NaN  NaN   NN    beautiful
# 24        (strong, JJ)  NaN  NaN  NaN   JJ       strong
#
# [864 rows x 6 columns]

# %%
new_col = pd.merge(df, df3, left_on = df3['b'], right_on= df['feature'])
new_col = new_col.rename(columns = {'a': 'pos_tag'})
new_col = new_col.drop(columns=['POS','1','2','3','4','b','key_0'])
left = new_col['pos_tag'].str[:1]
left = pd.DataFrame(left)
left = left.rename(columns={'pos_tag':'pos_tag_short'})

# %%
new_col
# Out:
#          feature     source pos_tag
# 0    accompanies      power     NNS
# 1       achieves      power     NNS
# 2        admires      power     NNS
# 3         admits      power     NNS
# 4         adores      power     NNS
# ..           ...        ...     ...
# 829          fat  Apperance      NN
# 830         weak  Apperance      JJ
# 831         thin  Apperance      NN
# 832       pretty  Apperance      RB
# 833    beautiful  Apperance      NN
#
# [834 rows x 3 columns]

# %%
pos_tags = new_col.join(left, on=new_col.index)

# %%
pos_tags['pos_tag_short'].value_counts()
# Out:
# N    668
# J    118
# V     38
# R     10
# Name: pos_tag_short, dtype: int64
