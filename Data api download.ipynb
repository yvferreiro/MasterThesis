# %%
#!pip install pynytimes

# %%
from pynytimes import NYTAPI

api_key = 'hjNcdKDgEhqfYWRqqvzTz1nyJ52eSPMc'

nyt = NYTAPI(api_key, parse_dates=True)

# %%
import datetime

articles = nyt.article_search(
    dates = {
        "begin": datetime.datetime(2010,1,1),
        "end": datetime.datetime(2010,1,31)
    },
    options = {
        "sort": "oldest",
        "sources": [
            "New York Times"
        ],
    }
)

# %%
articles

#Well, fuck. The full articles aren't here. FUCKKKKKK.
# Out:
# [{'abstract': '',
#   'web_url': 'https://cooking.nytimes.com/recipes/1012959-collard-greens-stuffed-with-raisins-nuts-and-rice',
#   'snippet': '',
#   'lead_paragraph': 'If greens, raisins, nuts and grains of rice all symbolize prosperity, then you’ll do well to make this recipe for your New Year’s Eve party. Collard greens are great stuffing leaves; they are large and easy to work with, and they can stand up to long simmering. The filling is a typical Greek dolmades filling.',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2010/01/01/health/nutrition/01recipehealth-collardgreens/01recipehealth-collardgreens-watch308-v2.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
# ...
