# %%
import pandas as pd
from functools import reduce
import pickle
import numpy as np
#pandas 1.4.4
#python version
#

# %%
file_path = r"C:\Users\danie\Documents\GitHub\Masters-Thesis\3--Results\LogReg\LogReg--Pickle HL Coef Results"
result = pd.read_pickle(file_path)
words = result["feature"].tolist()

# %%
len(words)
# Out:
# 22176

# %% [markdown]
# **Getting the Coefficients out of Log Reg**

# %%
open_path = "C:/Users/danie/Desktop/Masters Thesis/Log Reg Results/"

# %%
model_year = '2010'

with open(open_path + model_year +'_results.pkl', 'rb') as f:
    results = pickle.load(f)

vocabu = results['tfidf'].vocabulary_

word_vector = np.zeros(len(vocabu))
for word in words:
    if word in vocabu:
        index = vocabu[word]
        word_vector[index] = 1

coefficients = results['model'].coef_[0]
word_coefficients = {word: coefficient for word, coefficient in zip(vocabu.keys(), coefficients)}

coef_store = []

for word in words:
    if word in word_coefficients:
        coef_store.append((f"{word}, {word_coefficients[word]}"))

results_coef = pd.DataFrame(coef_store)
results_coef = pd.concat([results_coef[[0]], results_coef[0].str.split(', ', expand=True)], axis=1)
results_coef.set_axis(['drop', 'feature', model_year + '_coef'], axis='columns', inplace=True)
df = results_coef.drop(['drop'], axis=1)
df = df.drop_duplicates()

# %%
df
# Out:
#            feature            2010_coef
# 0             gone   -4.384912651575239
# 1           trolle  -0.7272764498146322
# 2          coiffed    -5.08291777402812
# 3           bungle   -6.367674261496876
# 4      fisherwoman   -6.037699873930361
# ...            ...                  ...
# 12249       misuse    3.698477597465851
# 12250    behaviour   -5.675093314584668
# 12251  congressman    2.084870987040412
# 12252        rikki   -4.147257354094423
# 12253      declare   -2.870405663639282
#
# [11668 rows x 2 columns]

# %%
year_list = ['2011', '2012', '2013', '2014', '2015',"2016", "2017", "2018", "2019", "2020", "2021", "2022"]

# %%
for year in year_list:

    with open(open_path + year +'_results.pkl', 'rb') as f:
        results = pickle.load(f)

    vocabu = results['tfidf'].vocabulary_

    word_vector = np.zeros(len(vocabu))
    for word in words:
        if word in vocabu:
            index = vocabu[word]
            word_vector[index] = 1

    coefficients = results['model'].coef_[0]
    word_coefficients = {word: coefficient for word, coefficient in zip(vocabu.keys(), coefficients)}

    coef_store = []

    for word in words:
        if word in word_coefficients:
            coef_store.append((f"{word}, {word_coefficients[word]}"))

    results_coef = pd.DataFrame(coef_store)
    results_coef = pd.concat([results_coef[[0]], results_coef[0].str.split(', ', expand=True)], axis=1)
    results_coef.set_axis(['drop', 'feature', year + '_coef'], axis='columns', inplace=True)
    merged_left = results_coef.drop(['drop'], axis=1)

    df = pd.merge(left = df, right = merged_left, how= 'inner', left_on=['feature'], right_on=['feature'])
    df = df.drop_duplicates()

# %%
df
# Out:
#           feature            2010_coef            2011_coef  \
# 0            gone   -4.384912651575239  -2.1445539107547607
# 1          bungle   -6.367674261496876   2.1239469686094044
# 2       headscarf  -3.9848623114896715   -5.120970675091346
# 3           paige  -2.4307092610347105   -2.031785907344614
# 4           warns    9.709787988741173  0.36137857651041916
# ...           ...                  ...                  ...
# 7347        hobby  -3.6907765406330224  -2.2021136455042236
# 7348       misuse    3.698477597465851   1.7045052024602159
# 7349    behaviour   -5.675093314584668  -0.3388671852003833
# 7350  congressman    2.084870987040412   0.8515481498637325
# 7351      declare   -2.870405663639282   -4.881957887260198
#
#                 2012_coef             2013_coef             2014_coef  \
# 0     -4.7854131451734325   -1.2581635818936523  -0.09857305787646065
# 1      -2.823161574166622     -5.77563798972506    -5.683603970763038
# 2      -8.109419089641557   -3.7078390779330905   -3.0549778725952286
# 3      0.8514798907288793    0.7952347780609019    -1.189464588747169
# 4       3.328702311748599   -3.5192009873623773     4.552155655319491
# ...                   ...                   ...                   ...
# 7347   1.9753467126212003   -3.6485738405160806    -7.726290229507128
# 7348  -3.5265241760381456  -0.42179457363515904     8.544389146529442
# 7349  -3.9839912227565595     4.013348686035082    -2.364830669061696
# 7350  -2.6767065759668465   -0.6250088196657303   -0.0820167779945176
# 7351                  0.0    1.4927884498959136  -0.18700534133183977
#
#                 2015_coef           2016_coef            2017_coef  \
# 0      -5.430849838407071   -3.60063236579318  -0.5099107503234959
# 1     -3.1210780648864254  0.4396708202617013  -3.3026024089730135
# 2     -0.3026250907757021   6.960609551298286  -0.5863249612555205
# 3      -7.348904799874906                 0.0    -4.86185642690244
# 4     -1.7220016708937524   3.359275241091586   -3.140241495187274
# ...                   ...                 ...                  ...
# 7347   -5.465404914250496    5.77340972100516   -3.372013643078436
# 7348   -2.001901739953176  -2.292454358929961   -5.250592267104021
# 7349  -1.8885764698232335  1.6723703477900003   -4.007304298429603
# 7350   1.5551272905861877  1.4749825239724552   -4.258185037368211
# 7351   13.834897052277997   2.771149055902789   -4.965632917350855
#
#                  2018_coef            2019_coef            2020_coef  \
# 0        2.721973214375057   -6.787539382664265  -2.2825349053429425
# 1      -2.1461989391270504   1.8757409156879246    5.322244250420093
# 2       -5.370054341563755                  0.0    6.506716129223749
# 3       2.1281808621236817     2.18381298528854  -3.3223413123916745
# 4        3.142045341056326    3.236452041882714                  0.0
# ...                    ...                  ...                  ...
# 7347  -0.12425203355107244  -1.3644711217076235   2.9183359419809487
# 7348    -2.375264201569764  -3.4923910782912313  -0.3144223450064162
# 7349    1.7989323189511162  -3.0146076816943412                  0.0
# 7350    3.8917347440155563  -1.6842111186089999  -1.7968436284728646
# 7351   0.36732188309222336   0.4957224658674098   -5.478325321201438
#
#                 2021_coef             2022_coef
# 0      4.1239278380148185                   0.0
# 1       1.287362363322358                   0.0
# 2     -1.1451846146415472  -0.13799214334892768
# 3     -0.5033254489890409  -0.36100482884033647
# 4     -0.7319709298311773    0.7034587437504181
# ...                   ...                   ...
# 7347   1.2255597248311338                   0.0
# 7348  -0.6221671236168043                   0.0
# 7349  -0.5786353086931215  -0.08078491644030181
# 7350   2.0569204682687525   0.24542185717417517
# 7351   1.3177155314181326    0.1435294249232223
#
# [7035 rows x 14 columns]

# %%
df.to_csv("LogReg CSV HL Complete Results")

# %%
file_name = "LogReg--Pickle HL Complete Results"

with open(file_name, 'wb') as handle:
    pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)
